# %% [markdown]
# <a href="https://colab.research.google.com/github/NadavFireman/One-Piece-NLP-Project/blob/main/One_Piece_NLP_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

PATH = '/content/drive/MyDrive/לימודים/תואר שני/שנה א/סמסטר ב/עיבוד שפה טבעית NLP/Project'
TOKEN = "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"
USERNAME = "NadavFireman"
REPO = "One-Piece-NLP-Project"

# בניית כתובת URL מאובטחת
repo_url = f"https://{TOKEN}@github.com/{USERNAME}/{REPO}.git"

if os.path.exists(PATH):
    os.chdir(PATH)
    print(f"✅ עברנו לתיקייה: {os.getcwd()}")

    # ניקוי הגדרות קודמות כדי למנוע התנגשויות
    # !rm -rf .git
    # !git init
    # !git config --global user.email "nadav@example.com"
    # !git config --global user.name "NadavFireman"

    # הוספת קבצים וביצוע Commit
    # !git add .
    # !git commit -m "Fresh sync from Colab with updated permissions"

    # הגדרת Remote ודחיפה
    # !git remote add origin {repo_url}
    # !git branch -M main

    print("\n🚀 מנסה לבצע Push ל-GitHub...")
    # !git push -u origin main -f
else:
    print(f"❌ שגיאה: הנתיב {PATH} לא נמצא.")
# Out:
# ✅ עברנו לתיקייה: /content/drive/MyDrive/לימודים/תואר שני/שנה א/סמסטר ב/עיבוד שפה טבעית NLP/Project
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/לימודים/תואר שני/שנה א/סמסטר ב/עיבוד שפה טבעית NLP/Project/.git/
# [master (root-commit) bffd6f5] Fresh sync from Colab with updated permissions
#  1 file changed, 1 insertion(+)
#  create mode 100644 One Piece NLP Project.ipynb
#
# 🚀 מנסה לבצע Push ל-GitHub...
# remote: Write access to repository not granted.
# ...

# %%
import requests

TOKEN = "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"
headers = {'Authorization': f'token {TOKEN}'}

# בדיקת פרטי הטוקן והרשאות
response = requests.get('https://api.github.com/user', headers=headers)
if response.status_code == 200:
    print(f"✅ מחובר כמשתמש: {response.json().get('login')}")

    # בדיקה ספציפית על הריפוזיטורי
    repo_url = "https://api.github.com/repos/NadavFireman/One-Piece-NLP-Project"
    repo_res = requests.get(repo_url, headers=headers)

    if repo_res.status_code == 200:
        permissions = repo_res.json().get('permissions', {})
        print(f"\nPermissions for this repo:")
        print(f"- Push (Write): {permissions.get('push')}")
        print(f"- Pull (Read): {permissions.get('pull')}")
        print(f"- Admin: {permissions.get('admin')}")

        if not permissions.get('push'):
            print("\n❌ אין לך הרשאת כתיבה! שנה ב-GitHub את ה-Token ל-Read and Write תחת Contents.")
    else:
        print(f"❌ לא הצלחתי למצוא את הריפוזיטורי. סטטוס: {repo_res.status_code}")
else:
    print(f"❌ הטוקן לא תקין או שפג תוקפו. סטטוס: {response.status_code}")
# Out:
# ✅ מחובר כמשתמש: NadavFireman
# ❌ לא הצלחתי למצוא את הריפוזיטורי. סטטוס: 404

# %%
import requests

TOKEN = "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"
headers = {'Authorization': f'token {TOKEN}'}

# בקשת רשימת הריפוזיטורים של המשתמש
response = requests.get('https://api.github.com/user/repos?per_page=100', headers=headers)

if response.status_code == 200:
    repos = response.json()
    print(f"✅ נמצאו {len(repos)} ריפוזיטורים תחת המשתמש NadavFireman:\n")
    found = False
    for r in repos:
        print(f"- {r['name']} (Visibility: {r['visibility']})")
        if r['name'].lower() == "one-piece-nlp-project".lower():
            found = True
            print(f"   ^--- שימו לב: זה השם המדויק שנמצא!")

    if not found:
        print("\n❌ הריפו 'One-Piece-NLP-Project' לא נמצא ברשימה. וודא שיצרת אותו ב-GitHub.")
else:
    print(f"❌ שגיאה בקבלת הרשימה: {response.status_code}")
# Out:
# ✅ נמצאו 21 ריפוזיטורים תחת המשתמש NadavFireman:
#
# - Advanced_Databases (Visibility: public)
# - Advanced_Programming_Python_FinalExam (Visibility: public)
# - Advanced_Programming_Python_HW1 (Visibility: public)
# - Advanced_Programming_Python_HW2 (Visibility: public)
# - Advanced_Programming_Python_HW3 (Visibility: public)
# - Advanced_Programming_Python_HW4 (Visibility: public)
# - Advanced_Programming_Python_HW5 (Visibility: public)
# - Advanced_Programming_Python_Test1 (Visibility: public)
# - Advanced_Programming_Python_Test2 (Visibility: public)
# - Advanced_Programming_Python_Test3 (Visibility: public)
# - Big_Data_HW1_Python_PySpark (Visibility: public)
# - Big_Data_HW2_Hadoop_Pig (Visibility: public)
# - Databases_SQL_FinalExam (Visibility: public)
# - Databases_SQL_HW1 (Visibility: public)
# - Databases_SQL_HW2 (Visibility: public)
# - Databases_SQL_HW3 (Visibility: public)
# - IAF-Resource-Optimization (Visibility: public)
# ...

# %%
import os

# הגדרות
PATH = '/content/drive/MyDrive/לימודים/תואר שני/שנה א/סמסטר ב/עיבוד שפה טבעית NLP/Project'
TOKEN = "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"
USERNAME = "NadavFireman"
REPO = "One-Piece-NLP-Project"
repo_url = f"https://{TOKEN}@github.com/{USERNAME}/{REPO}.git"

if os.path.exists(PATH):
    os.chdir(PATH)
    print(f"✅ עברנו לתיקייה: {os.getcwd()}")

    # הגדרות Git
    # !git config --global user.email "nadav@example.com"
    # !git config --global user.name "NadavFireman"

    # אתחול מחדש כדי לוודא שאין שאריות של טוקן ישן
    # !rm -rf .git
    # !git init
    # !git add .
    # !git commit -m "Sync from Google Colab"

    # חיבור ודחיפה
    # !git remote add origin {repo_url}
    # !git branch -M main

    print("\n🚀 מנסה לבצע Push ל-GitHub...")
    # !git push -u origin main -f
else:
    print(f"❌ שגיאה: הנתיב {PATH} לא נמצא.")
# Out:
# ✅ עברנו לתיקייה: /content/drive/MyDrive/לימודים/תואר שני/שנה א/סמסטר ב/עיבוד שפה טבעית NLP/Project
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/לימודים/תואר שני/שנה א/סמסטר ב/עיבוד שפה טבעית NLP/Project/.git/
# [master (root-commit) f20f1fb] Sync from Google Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 One Piece NLP Project.ipynb
#
# 🚀 מנסה לבצע Push ל-GitHub...
# remote: Write access to repository not granted.
# ...
